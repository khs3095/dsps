# %% [markdown]
# ### change path below to your gdrive path where folder is

# %%
# Out:
# /content/drive/MyDrive/pavement_competition/new_test/DSPS

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/MyDrive/DSPS'
# Out:
# /content/drive/MyDrive/DSPS

# %%
# # Uncomment the lines below to download training data
# !gdown 'https://drive.google.com/uc?id=1I1onAA61iui4LjOxejkxioaBjU1Ic_6X'
# !unzip 'training_data.zip' -d './cvat'

# %%
# cvat folder should contain 3 folders: td1, td2, td3
# !ls cvat
# Out:
# td1  td2  td3  td4

# %% [markdown]
# ## Uncomment and run codes below if this is the first time running this notebook

# %%
# !pip install -U PyYAML

# %%
# !pip install -qr dspYolov5/requirements.txt  # install dependencies for yolov5

# %% [markdown]
# ## Uncomment block of codes in cell below to convert cvat annotations to yolo annotations

# %%
import os
from dsps.simple_fxn import cvat2yolo
# location of cvat annotations
annotation_folder = 'cvat/'
output_path = 'data/training'
val_path = 'data/validation'
for annts in os.listdir(annotation_folder):
  json_file = os.path.join(annotation_folder,annts,'annotations','instances_default.json')
  img_path = os.path.join(annotation_folder,annts,'images')
  if(os.path.isfile(json_file)):
    cvat2yolo(annts,json_file,img_path, output_path, val_path)
# Out:
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['TRANSVERSE', 'PATCHING', 'BLOCK', 'LONGITUDINAL', 'ALLIGATOR', 'SEALING', 'MANHOLE']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['TRANSVERSE', 'PATCHING', 'LONGITUDINAL', 'BLOCK', 'ALLIGATOR', 'SEALING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['LONGITUDINAL', 'BLOCK', 'TRANSVERSE', 'ALLIGATOR', 'MANHOLE', 'PATCHING', 'SEALING']
# {1: 'ALLIGATOR', 2: 'BLOCK', 3: 'TRANSVERSE', 4: 'PATCHING', 5: 'SEALING', 6: 'LONGITUDINAL', 7: 'MANHOLE'}
# total number of classes: 7
# ['LONGITUDINAL', 'BLOCK', 'TRANSVERSE', 'ALLIGATOR', 'PATCHING', 'SEALING', 'MANHOLE']

# %% [markdown]
# ## Train a new model

# %% [markdown]
# ### If not running on GPU, change runtime to GPU
# ________

# %%
import json
import torch
from IPython.display import Image, clear_output  # to display images

clear_output()
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")
# Out:
# Setup complete. Using torch 1.10.0+cu111 (Tesla T4)

# %% [markdown]
# ### **Change class labels and number of classes**:
# * Edit dspYolov5/data/dsps.yaml file
# ### **Change model configuration**:
# * Edit dspYolov5/models/dsps_model.yaml

# %% [markdown]
# ### run the code below. You may get an error the first time.
#
# ---
#
# restart the runtime and run again.
#
# stop cell after total epoch have elapsed.

# %%
# !python -i dspYolov5/train_dsps.py --data dspYolov5/data/dsps.yaml --cfg dspYolov5/models/dsps_model.yaml --batch-size 8 --device 0 --hyp
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 30.6MB/s]
# train: weights=yolov5s.pt, cfg=dspYolov5/models/dsps_model.yaml, data=dspYolov5/data/dsps.yaml, hyp=data/hyps/hyp.scratch.yaml, epochs=150, batch_size=8, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, adam=False, sync_bn=False, workers=8, project=weights/train, entity=None, name=exp, exist_ok=False, quad=False, linear_lr=False, label_smoothing=0.0, upload_dataset=False, bbox_interval=-1, save_period=-1, artifact_alias=latest, local_rank=-1, freeze=0, patience=100
# github: Command 'git fetch && git config --get remote.origin.url' timed out after 5 seconds
# YOLOv5 🚀 119ab33 torch 1.10.0+cu111 CUDA:0 (Tesla T4, 15109.75MB)
#
# hyperparameters: lr0=0.01, lrf=0.2, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# Weights & Biases: run 'pip install wandb' to automatically track and visualize YOLOv5 🚀 runs (RECOMMENDED)
# TensorBoard: Start with 'tensorboard --logdir weights/train', view at http://localhost:6006/
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Focus                     [3, 32, 3]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  3    156928  models.common.C3                        [128, 128, 3]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1    656896  models.common.SPP                       [512, 512, [5, 9, 13]]
#   9                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     32364  models.yolo.Detect                      [7, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# Model Summary: 283 layers, 7079724 parameters, 7079724 gradients, 16.4 GFLOPs
#
# Transferred 354/362 items from yolov5s.pt
# Scaled weight_decay = 0.0005
# optimizer: SGD with parameter groups 59 weight, 62 weight (no decay), 62 bias
# albumentations: version 1.0.3 required by YOLOv5, but version 0.1.12 is currently installed
# train: Scanning 'data/training' images and labels...311 found, 12 missing, 0 empty, 0 corrupted: 100% 323/323 [00:00<00:00, 337.14it/s]
# train: New cache created: data/training.cache
# val: Scanning 'data/validation' images and labels...79 found, 1 missing, 0 empty, 0 corrupted: 100% 80/80 [00:00<00:00, 162.97it/s]
# val: New cache created: data/validation.cache
# Plotting labels...
#
# autoanchor: Analyzing anchors... anchors/target = 3.12, Best Possible Recall (BPR) = 0.9340. Attempting to improve anchors, please wait...
# autoanchor: WARNING: Extremely small objects found. 14 of 1515 labels are < 3 pixels in size.
# autoanchor: Running kmeans for 9 anchors on 1515 points...
# autoanchor: thr=0.25: 0.9254 best possible recall, 2.72 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.208/0.555-mean/best, past_thr=0.441-mean: 16,40,  73,49,  26,155,  164,93,  290,67,  65,326,  35,608,  257,330,  208,611
# autoanchor: Evolving anchors with Genetic Algorithm: fitness = 0.6374: 100% 1000/1000 [00:00<00:00, 1764.84it/s]
# autoanchor: thr=0.25: 0.9960 best possible recall, 2.73 anchors past thr
# autoanchor: n=9, img_size=640, metric_all=0.213/0.638-mean/best, past_thr=0.458-mean: 7,32,  49,16,  14,95,  67,73,  229,40,  21,424,  79,242,  203,169,  213,492
# autoanchor: New anchors saved to model. Update model *.yaml to use these anchors in the future.
#
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to weights/train/exp
# Starting training for 150 epochs...
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      0/149     1.91G    0.1223   0.03769   0.06007        59       640: 100% 41/41 [00:36<00:00,  1.13it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.93it/s]
#                  all         80        370   0.000959      0.117   0.000664   0.000119
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      1/149        2G     0.113     0.039   0.05706        21       640: 100% 41/41 [00:35<00:00,  1.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.81it/s]
#                  all         80        370    0.00439     0.0634    0.00228   0.000476
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      2/149        2G    0.1044   0.04306   0.05283        26       640: 100% 41/41 [00:34<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.99it/s]
#                  all         80        370     0.0147     0.0468    0.00628    0.00125
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      3/149        2G   0.09601   0.04519    0.0485        20       640: 100% 41/41 [00:34<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.99it/s]
#                  all         80        370     0.0287      0.124     0.0285    0.00698
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      4/149        2G   0.09087   0.04567   0.04467        26       640: 100% 41/41 [00:34<00:00,  1.17it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.04it/s]
#                  all         80        370      0.379      0.076     0.0609     0.0209
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      5/149        2G   0.08677   0.04929   0.04012        22       640: 100% 41/41 [00:35<00:00,  1.16it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.90it/s]
#                  all         80        370      0.667      0.101     0.0834     0.0324
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#      6/149        2G   0.08202   0.04741   0.03701        19       640: 100% 41/41 [00:34<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    142/149        2G     0.033   0.02632  0.004004        31       640: 100% 41/41 [00:34<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.06it/s]
#                  all         80        370      0.477      0.507      0.468      0.251
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    143/149        2G   0.03339   0.02731   0.00427        30       640: 100% 41/41 [00:34<00:00,  1.18it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.01it/s]
#                  all         80        370      0.473      0.486       0.47      0.274
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    144/149        2G    0.0324   0.02637  0.003775        55       640: 100% 41/41 [00:34<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.03it/s]
#                  all         80        370      0.482       0.49      0.475      0.276
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    145/149        2G   0.03186   0.02428  0.003853        19       640: 100% 41/41 [00:34<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.99it/s]
#                  all         80        370      0.522      0.472      0.464      0.271
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    146/149        2G   0.03261   0.02588  0.003844        34       640: 100% 41/41 [00:34<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.00it/s]
#                  all         80        370      0.455      0.488      0.446      0.246
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    147/149        2G   0.03171   0.02553  0.003759        29       640: 100% 41/41 [00:34<00:00,  1.19it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  1.96it/s]
#                  all         80        370      0.525      0.448      0.449      0.242
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    148/149        2G   0.03223   0.02649  0.003208        34       640: 100% 41/41 [00:34<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:02<00:00,  2.05it/s]
#                  all         80        370      0.467      0.487      0.459      0.248
#
#      Epoch   gpu_mem       box       obj       cls    labels  img_size
#    149/149        2G   0.03213   0.02704  0.003215        35       640: 100% 41/41 [00:34<00:00,  1.20it/s]
#                Class     Images     Labels          P          R     mAP@.5 mAP@.5:.95: 100% 5/5 [00:05<00:00,  1.16s/it]
#                  all         80        370      0.542      0.459      0.461      0.271
#            ALLIGATOR         80         39      0.512      0.333      0.299      0.142
#                BLOCK         80         19      0.401      0.211      0.253      0.106
#           TRANSVERSE         80        103      0.525      0.466      0.393      0.148
#             PATCHING         80         34      0.853      0.853      0.895       0.64
#              SEALING         80         14      0.482      0.214      0.267       0.13
#         LONGITUDINAL         80        160      0.347      0.136      0.124     0.0378
#              MANHOLE         80          1      0.673          1      0.995      0.697
#
# 150 epochs completed in 1.605 hours.
# Optimizer stripped from weights/train/exp/weights/last.pt, 14.4MB
# Optimizer stripped from weights/train/exp/weights/best.pt, 14.4MB
# Results saved to weights/train/exp
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>>
# KeyboardInterrupt
# >>> ^C

# %% [markdown]
# ### Evaluate and Visualize Model Performance
#
# #### change weights path in the following cell: replace exp12 in the weights path with your corresponding folder-- 'weights/train/exp12/weights/best.pt'

# %%
# Uncomment the lines below to download training data
# !gdown 'https://drive.google.com/uc?id=1TtDGMgTyrH6bclBf76ggZk28N9aalOzc'
# !unzip 'dsps_test.zip' -d './data/test_images'
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1TtDGMgTyrH6bclBf76ggZk28N9aalOzc
# To: /content/drive/MyDrive/DSPS/dsps_test.zip
# 100% 330M/330M [00:02<00:00, 140MB/s]
# Archive:  dsps_test.zip
# replace ./data/test_images/images/5 (7).JPG? [y]es, [n]o, [A]ll, [N]one, [r]ename: N

# %%
## create results folder if it doen't exist

# %%
# !python 'dspYolov5/detect_dsps.py' --weights 'weights/train/exp/weights/best.pt' --img 640 --conf 0.25 --source data/test_images/images
# Out:
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 14.4MB/s]
# detect: weights=['weights/train/exp/weights/best.pt'], source=data/test_images/images, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False
# requirements: /content/drive/MyDrive/DSPS/requirements.txt not found, check failed.
# YOLOv5 🚀 119ab33 torch 1.10.0+cu111 CPU
#
# Fusing layers...
# Model Summary: 224 layers, 7070092 parameters, 0 gradients
# /usr/local/lib/python3.7/dist-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (16).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 TRANSVERSEs, Done. (0.373s)
# image 2/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (17).JPG: 640x352 3 ALLIGATORs, 1 BLOCK, 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.248s)
# image 3/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (18).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 TRANSVERSEs, 3 PATCHINGs, 2 LONGITUDINALs, Done. (0.239s)
# image 4/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (19).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.267s)
# image 5/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (20).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.242s)
# image 6/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (21).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.252s)
# image 7/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (22).JPG: 640x352 Done. (0.282s)
# image 8/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (23).JPG: 640x352 1 TRANSVERSE, Done. (0.253s)
# image 9/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (24).JPG: 640x352 Done. (0.250s)
# image 10/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (25).JPG: 640x352 Done. (0.260s)
# image 11/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (26).JPG: 640x352 Done. (0.249s)
# image 12/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (27).JPG: 640x352 Done. (0.249s)
# image 13/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (28).JPG: 640x352 1 MANHOLE, Done. (0.250s)
# image 14/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (29).JPG: 640x352 Done. (0.263s)
# image 15/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (30).JPG: 640x352 Done. (0.251s)
# image 16/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (31).JPG: 640x352 Done. (0.249s)
# image 17/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (32).JPG: 640x352 Done. (0.256s)
# image 18/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (33).JPG: 640x352 Done. (0.248s)
# image 19/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (34).JPG: 640x352 Done. (0.247s)
# image 20/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (35).JPG: 640x352 Done. (0.277s)
# image 21/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (36).JPG: 640x352 Done. (0.252s)
# image 22/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (37).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.252s)
# image 23/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (38).JPG: 640x352 1 ALLIGATOR, Done. (0.250s)
# image 24/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (39).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 TRANSVERSEs, Done. (0.253s)
# image 25/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (40).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, 1 PATCHING, Done. (0.257s)
# image 26/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (41).JPG: 640x352 4 ALLIGATORs, Done. (0.243s)
# image 27/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (42).JPG: 640x352 1 ALLIGATOR, 5 TRANSVERSEs, Done. (0.252s)
# image 28/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (43).JPG: 640x352 2 ALLIGATORs, 1 LONGITUDINAL, Done. (0.244s)
# image 29/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (44).JPG: 640x352 2 ALLIGATORs, 2 TRANSVERSEs, Done. (0.248s)
# image 30/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (45).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.247s)
# image 31/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (46).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.246s)
# image 32/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (47).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.246s)
# image 33/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (48).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 4 LONGITUDINALs, Done. (0.248s)
# image 34/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (49).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.245s)
# image 35/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (50).JPG: 640x352 2 ALLIGATORs, 1 LONGITUDINAL, Done. (0.253s)
# image 36/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (51).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.253s)
# image 37/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (52).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 5 TRANSVERSEs, 5 LONGITUDINALs, Done. (0.248s)
# image 38/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (53).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 4 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.248s)
# image 39/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (54).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 5 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.251s)
# image 40/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (55).JPG: 640x352 1 ALLIGATOR, 5 TRANSVERSEs, 4 LONGITUDINALs, Done. (0.245s)
# image 41/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (56).JPG: 640x352 5 TRANSVERSEs, 4 LONGITUDINALs, Done. (0.244s)
# image 42/352 /content/drive/MyDrive/DSPS/data/test_images/images/1 (57).JPG: 640x352 2 ALLIGATORs, 7 TRANSVERSEs, Done. (0.252s)
# image 43/352 /content/drive/MyDrive/DSPS/data/test_images/images/4 (66).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.242s)
# image 44/352 /content/drive/MyDrive/DSPS/data/test_images/images/4 (67).JPG: 640x352 2 LONGITUDINALs, Done. (0.253s)
# image 45/352 /content/drive/MyDrive/DSPS/data/test_images/images/4 (68).JPG: 640x352 2 TRANSVERSEs, Done. (0.252s)
# image 46/352 /content/drive/MyDrive/DSPS/data/test_images/images/4 (69).JPG: 640x352 1 TRANSVERSE, Done. (0.251s)
# image 47/352 /content/drive/MyDrive/DSPS/data/test_images/images/4 (70).JPG: 640x352 1 BLOCK, 1 PATCHING, Done. (0.241s)
# image 48/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (1).JPG: 640x352 1 LONGITUDINAL, Done. (0.255s)
# image 49/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (10).JPG: 640x352 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, Done. (0.244s)
# image 50/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (11).JPG: 640x352 1 BLOCK, Done. (0.255s)
# image 51/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (12).JPG: 640x352 1 MANHOLE, Done. (0.259s)
# image 52/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (13).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.254s)
# image 53/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (14).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, Done. (0.245s)
# image 54/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (15).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, Done. (0.249s)
# image 55/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (16).JPG: 640x352 2 ALLIGATORs, 1 PATCHING, 2 LONGITUDINALs, Done. (0.241s)
# image 56/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (17).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.251s)
# image 57/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (18).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.240s)
# image 58/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (19).JPG: 640x352 3 LONGITUDINALs, Done. (0.248s)
# image 59/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (2).JPG: 640x352 1 ALLIGATOR, Done. (0.253s)
# image 60/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (20).JPG: 640x352 2 LONGITUDINALs, Done. (0.245s)
# image 61/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (21).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.246s)
# image 62/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (22).JPG: 640x352 1 PATCHING, 2 LONGITUDINALs, 1 MANHOLE, Done. (0.252s)
# image 63/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (23).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.246s)
# image 64/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (24).JPG: 640x352 2 TRANSVERSEs, Done. (0.250s)
# image 65/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (25).JPG: 640x352 1 BLOCK, 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.257s)
# image 66/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (26).JPG: 640x352 3 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.247s)
# image 67/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (27).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, Done. (0.241s)
# image 68/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (28).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.248s)
# image 69/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (29).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, Done. (0.244s)
# image 70/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (3).JPG: 640x352 2 ALLIGATORs, 4 TRANSVERSEs, 1 LONGITUDINAL, 1 MANHOLE, Done. (0.261s)
# image 71/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (30).JPG: 640x352 Done. (0.245s)
# image 72/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (31).JPG: 640x352 1 ALLIGATOR, 1 LONGITUDINAL, Done. (0.250s)
# image 73/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (32).JPG: 640x352 1 ALLIGATOR, 1 LONGITUDINAL, Done. (0.253s)
# image 74/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (33).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.250s)
# image 75/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (34).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 MANHOLE, Done. (0.241s)
# image 76/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (35).JPG: 640x352 Done. (0.250s)
# image 77/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (36).JPG: 640x352 1 LONGITUDINAL, Done. (0.240s)
# image 78/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (37).JPG: 640x352 2 TRANSVERSEs, 2 PATCHINGs, 3 LONGITUDINALs, 1 MANHOLE, Done. (0.248s)
# image 79/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (38).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.254s)
# image 80/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (39).JPG: 640x352 2 ALLIGATORs, 2 LONGITUDINALs, Done. (0.244s)
# image 81/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (4).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 1 PATCHING, Done. (0.242s)
# image 82/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (40).JPG: 640x352 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.253s)
# image 83/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (41).JPG: 640x352 1 LONGITUDINAL, Done. (0.238s)
# image 84/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (42).JPG: 640x352 1 BLOCK, 1 PATCHING, 4 LONGITUDINALs, Done. (0.249s)
# image 85/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (43).JPG: 640x352 1 BLOCK, 1 PATCHING, 2 LONGITUDINALs, Done. (0.247s)
# image 86/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (44).JPG: 640x352 1 TRANSVERSE, Done. (0.242s)
# image 87/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (45).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.247s)
# image 88/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (46).JPG: 640x352 3 TRANSVERSEs, Done. (0.247s)
# image 89/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (47).JPG: 640x352 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.245s)
# image 90/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (48).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.252s)
# image 91/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (49).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, Done. (0.245s)
# image 92/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (5).JPG: 640x352 1 ALLIGATOR, 1 LONGITUDINAL, Done. (0.252s)
# image 93/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (50).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.246s)
# image 94/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (51).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.246s)
# image 95/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (52).JPG: 640x352 1 TRANSVERSE, Done. (0.255s)
# image 96/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (53).JPG: 640x352 1 ALLIGATOR, Done. (0.247s)
# image 97/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (54).JPG: 640x352 1 TRANSVERSE, Done. (0.245s)
# image 98/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (55).JPG: 640x352 Done. (0.244s)
# image 99/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (56).JPG: 640x352 1 LONGITUDINAL, Done. (0.239s)
# image 100/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (57).JPG: 640x352 1 TRANSVERSE, Done. (0.251s)
# image 101/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (58).JPG: 640x352 1 TRANSVERSE, Done. (0.244s)
# image 102/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (59).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.244s)
# image 103/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (6).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.246s)
# image 104/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (60).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, 2 MANHOLEs, Done. (0.241s)
# image 105/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (61).JPG: 640x352 1 TRANSVERSE, 3 LONGITUDINALs, Done. (0.249s)
# image 106/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (62).JPG: 640x352 1 PATCHING, Done. (0.243s)
# image 107/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (63).JPG: 640x352 Done. (0.236s)
# image 108/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (64).JPG: 640x352 1 TRANSVERSE, Done. (0.243s)
# image 109/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (65).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.244s)
# image 110/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (66).JPG: 640x352 3 TRANSVERSEs, Done. (0.251s)
# image 111/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (67).JPG: 640x352 1 BLOCK, 1 PATCHING, 2 MANHOLEs, Done. (0.246s)
# image 112/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (68).JPG: 640x352 2 TRANSVERSEs, Done. (0.248s)
# image 113/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (69).JPG: 640x352 Done. (0.246s)
# image 114/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (7).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 LONGITUDINAL, Done. (0.246s)
# image 115/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (70).JPG: 640x352 Done. (0.252s)
# image 116/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (71).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, Done. (0.250s)
# image 117/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (72).JPG: 640x352 1 TRANSVERSE, 2 PATCHINGs, Done. (0.242s)
# image 118/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (73).JPG: 640x352 1 PATCHING, 1 MANHOLE, Done. (0.248s)
# image 119/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (74).JPG: 640x352 2 TRANSVERSEs, Done. (0.246s)
# image 120/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (75).JPG: 640x352 Done. (0.262s)
# image 121/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (76).JPG: 640x352 2 TRANSVERSEs, Done. (0.243s)
# image 122/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (77).JPG: 640x352 1 TRANSVERSE, Done. (0.250s)
# image 123/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (78).JPG: 640x352 Done. (0.244s)
# image 124/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (79).JPG: 640x352 Done. (0.241s)
# image 125/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (8).JPG: 640x352 1 ALLIGATOR, Done. (0.256s)
# image 126/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (80).JPG: 640x352 1 ALLIGATOR, Done. (0.244s)
# image 127/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (81).JPG: 640x352 2 TRANSVERSEs, Done. (0.244s)
# image 128/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (82).JPG: 640x352 Done. (0.241s)
# image 129/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (83).JPG: 640x352 1 LONGITUDINAL, Done. (0.241s)
# image 130/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (84).JPG: 640x352 2 TRANSVERSEs, Done. (0.251s)
# image 131/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (85).JPG: 640x352 1 TRANSVERSE, Done. (0.239s)
# image 132/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (86).JPG: 640x352 2 LONGITUDINALs, Done. (0.255s)
# image 133/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (87).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.237s)
# image 134/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (88).JPG: 640x352 3 ALLIGATORs, Done. (0.237s)
# image 135/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (89).JPG: 640x352 Done. (0.242s)
# image 136/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (9).JPG: 640x352 3 ALLIGATORs, 1 BLOCK, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.244s)
# image 137/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (90).JPG: 640x352 2 ALLIGATORs, 5 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.251s)
# image 138/352 /content/drive/MyDrive/DSPS/data/test_images/images/5 (91).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.244s)
# image 139/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (1).JPG: 640x352 3 ALLIGATORs, 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.245s)
# image 140/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (10).JPG: 640x352 3 TRANSVERSEs, 1 LONGITUDINAL, 1 MANHOLE, Done. (0.252s)
# image 141/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (11).JPG: 640x352 Done. (0.256s)
# image 142/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (12).JPG: 640x352 1 ALLIGATOR, Done. (0.250s)
# image 143/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (13).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.252s)
# image 144/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (14).JPG: 640x352 2 TRANSVERSEs, 2 PATCHINGs, 1 LONGITUDINAL, Done. (0.265s)
# image 145/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (15).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.243s)
# image 146/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (16).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.243s)
# image 147/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (17).JPG: 640x352 2 BLOCKs, 1 TRANSVERSE, 1 PATCHING, Done. (0.243s)
# image 148/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (18).JPG: 640x352 1 ALLIGATOR, 2 BLOCKs, 1 TRANSVERSE, 2 PATCHINGs, Done. (0.244s)
# image 149/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (19).JPG: 640x352 1 TRANSVERSE, 2 PATCHINGs, 1 LONGITUDINAL, Done. (0.241s)
# image 150/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (2).JPG: 640x352 1 BLOCK, 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.245s)
# image 151/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (20).JPG: 640x352 1 BLOCK, Done. (0.252s)
# image 152/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (21).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, Done. (0.239s)
# image 153/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (22).JPG: 640x352 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, Done. (0.249s)
# image 154/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (23).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, Done. (0.270s)
# image 155/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (24).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.247s)
# image 156/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (25).JPG: 640x352 Done. (0.257s)
# image 157/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (26).JPG: 640x352 2 TRANSVERSEs, Done. (0.245s)
# image 158/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (27).JPG: 640x352 1 BLOCK, 1 MANHOLE, Done. (0.252s)
# image 159/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (28).JPG: 640x352 1 BLOCK, 1 LONGITUDINAL, Done. (0.244s)
# image 160/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (29).JPG: 640x352 1 BLOCK, 5 TRANSVERSEs, 1 PATCHING, 1 LONGITUDINAL, Done. (0.258s)
# image 161/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (3).JPG: 640x352 1 LONGITUDINAL, Done. (0.244s)
# image 162/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (30).JPG: 640x352 2 BLOCKs, 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.252s)
# image 163/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (31).JPG: 640x352 1 TRANSVERSE, 4 LONGITUDINALs, Done. (0.244s)
# image 164/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (32).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.248s)
# image 165/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (33).JPG: 640x352 2 LONGITUDINALs, Done. (0.246s)
# image 166/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (34).JPG: 640x352 2 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.255s)
# image 167/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (35).JPG: 640x352 2 TRANSVERSEs, Done. (0.260s)
# image 168/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (36).JPG: 640x352 Done. (0.249s)
# image 169/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (37).JPG: 640x352 1 PATCHING, 2 LONGITUDINALs, Done. (0.254s)
# image 170/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (38).JPG: 640x352 2 PATCHINGs, 2 LONGITUDINALs, Done. (0.238s)
# image 171/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (39).JPG: 640x352 1 BLOCK, 2 LONGITUDINALs, Done. (0.241s)
# image 172/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (4).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.243s)
# image 173/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (40).JPG: 640x352 1 LONGITUDINAL, Done. (0.248s)
# image 174/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (41).JPG: 640x352 1 ALLIGATOR, 1 LONGITUDINAL, Done. (0.241s)
# image 175/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (42).JPG: 640x352 1 TRANSVERSE, Done. (0.246s)
# image 176/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (43).JPG: 640x352 1 LONGITUDINAL, Done. (0.247s)
# image 177/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (44).JPG: 640x352 1 LONGITUDINAL, 1 MANHOLE, Done. (0.249s)
# image 178/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (45).JPG: 640x352 1 ALLIGATOR, 3 LONGITUDINALs, Done. (0.262s)
# image 179/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (46).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.240s)
# image 180/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (47).JPG: 640x352 Done. (0.248s)
# image 181/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (48).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.241s)
# image 182/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (49).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, Done. (0.249s)
# image 183/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (5).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.243s)
# image 184/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (50).JPG: 640x352 Done. (0.243s)
# image 185/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (51).JPG: 640x352 1 TRANSVERSE, Done. (0.246s)
# image 186/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (52).JPG: 640x352 3 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.253s)
# image 187/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (53).JPG: 640x352 1 TRANSVERSE, Done. (0.245s)
# image 188/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (54).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.245s)
# image 189/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (55).JPG: 640x352 1 TRANSVERSE, Done. (0.244s)
# image 190/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (56).JPG: 640x352 Done. (0.245s)
# image 191/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (57).JPG: 640x352 1 TRANSVERSE, Done. (0.255s)
# image 192/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (58).JPG: 640x352 1 TRANSVERSE, Done. (0.245s)
# image 193/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (59).JPG: 640x352 1 PATCHING, Done. (0.251s)
# image 194/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (6).JPG: 640x352 1 BLOCK, 2 LONGITUDINALs, Done. (0.248s)
# image 195/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (60).JPG: 640x352 1 LONGITUDINAL, Done. (0.257s)
# image 196/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (61).JPG: 640x352 1 TRANSVERSE, Done. (0.243s)
# image 197/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (62).JPG: 640x352 Done. (0.254s)
# image 198/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (63).JPG: 640x352 1 TRANSVERSE, Done. (0.255s)
# image 199/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (64).JPG: 640x352 2 TRANSVERSEs, Done. (0.248s)
# image 200/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (65).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.241s)
# image 201/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (66).JPG: 640x352 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.242s)
# image 202/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (67).JPG: 640x352 Done. (0.242s)
# image 203/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (68).JPG: 640x352 Done. (0.243s)
# image 204/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (7).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.247s)
# image 205/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (8).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, Done. (0.242s)
# image 206/352 /content/drive/MyDrive/DSPS/data/test_images/images/6 (9).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.244s)
# image 207/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (1).JPG: 640x352 1 ALLIGATOR, Done. (0.246s)
# image 208/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (10).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, Done. (0.241s)
# image 209/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (11).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 MANHOLE, Done. (0.245s)
# image 210/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (12).JPG: 640x352 2 ALLIGATORs, 3 TRANSVERSEs, Done. (0.241s)
# image 211/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (13).JPG: 640x352 3 ALLIGATORs, 2 TRANSVERSEs, 2 PATCHINGs, 2 LONGITUDINALs, Done. (0.239s)
# image 212/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (14).JPG: 640x352 2 ALLIGATORs, 2 TRANSVERSEs, 1 PATCHING, Done. (0.245s)
# image 213/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (15).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, Done. (0.244s)
# image 214/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (16).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.253s)
# image 215/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (17).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, Done. (0.242s)
# image 216/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (18).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.254s)
# image 217/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (19).JPG: 640x352 1 ALLIGATOR, Done. (0.244s)
# image 218/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (2).JPG: 640x352 1 TRANSVERSE, Done. (0.253s)
# image 219/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (20).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 1 LONGITUDINAL, 1 MANHOLE, Done. (0.260s)
# image 220/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (21).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.249s)
# image 221/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (22).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, Done. (0.240s)
# image 222/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (23).JPG: 640x352 1 BLOCK, 4 TRANSVERSEs, Done. (0.245s)
# image 223/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (24).JPG: 640x352 2 LONGITUDINALs, Done. (0.246s)
# image 224/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (25).JPG: 640x352 1 BLOCK, 3 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.251s)
# image 225/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (26).JPG: 640x352 2 ALLIGATORs, 2 TRANSVERSEs, Done. (0.243s)
# image 226/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (27).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, Done. (0.257s)
# image 227/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (28).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.245s)
# image 228/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (29).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, 1 MANHOLE, Done. (0.249s)
# image 229/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (3).JPG: 640x352 1 ALLIGATOR, Done. (0.238s)
# image 230/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (30).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.252s)
# image 231/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (31).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.241s)
# image 232/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (32).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 1 MANHOLE, Done. (0.249s)
# image 233/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (33).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 2 LONGITUDINALs, 1 MANHOLE, Done. (0.240s)
# image 234/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (34).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.254s)
# image 235/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (35).JPG: 640x352 1 BLOCK, 1 LONGITUDINAL, Done. (0.239s)
# image 236/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (36).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, Done. (0.246s)
# image 237/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (37).JPG: 640x352 4 ALLIGATORs, 2 TRANSVERSEs, 2 PATCHINGs, 1 MANHOLE, Done. (0.252s)
# image 238/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (38).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 2 PATCHINGs, Done. (0.257s)
# image 239/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (39).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.260s)
# image 240/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (4).JPG: 640x352 1 TRANSVERSE, Done. (0.248s)
# image 241/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (40).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.237s)
# image 242/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (41).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, 1 TRANSVERSE, Done. (0.247s)
# image 243/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (42).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.244s)
# image 244/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (43).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 1 PATCHING, Done. (0.238s)
# image 245/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (44).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, 1 LONGITUDINAL, Done. (0.247s)
# image 246/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (45).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.243s)
# image 247/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (46).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.246s)
# image 248/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (47).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, Done. (0.240s)
# image 249/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (48).JPG: 640x352 2 ALLIGATORs, Done. (0.245s)
# image 250/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (49).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 1 PATCHING, 2 LONGITUDINALs, Done. (0.239s)
# image 251/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (5).JPG: 640x352 2 LONGITUDINALs, Done. (0.244s)
# image 252/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (50).JPG: 640x352 1 BLOCK, 2 PATCHINGs, 1 SEALING, 1 LONGITUDINAL, Done. (0.240s)
# image 253/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (51).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.250s)
# image 254/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (52).JPG: 640x352 3 ALLIGATORs, Done. (0.241s)
# image 255/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (53).JPG: 640x352 2 ALLIGATORs, Done. (0.251s)
# image 256/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (54).JPG: 640x352 2 ALLIGATORs, Done. (0.245s)
# image 257/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (55).JPG: 640x352 5 ALLIGATORs, Done. (0.252s)
# image 258/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (56).JPG: 640x352 5 ALLIGATORs, 1 BLOCK, 1 TRANSVERSE, 1 MANHOLE, Done. (0.259s)
# image 259/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (57).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.241s)
# image 260/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (58).JPG: 640x352 3 ALLIGATORs, Done. (0.241s)
# image 261/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (59).JPG: 640x352 2 ALLIGATORs, 1 LONGITUDINAL, Done. (0.237s)
# image 262/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (6).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.241s)
# image 263/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (60).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, Done. (0.244s)
# image 264/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (61).JPG: 640x352 2 ALLIGATORs, Done. (0.266s)
# image 265/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (62).JPG: 640x352 2 ALLIGATORs, Done. (0.247s)
# image 266/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (63).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, Done. (0.243s)
# image 267/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (64).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.242s)
# image 268/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (65).JPG: 640x352 1 ALLIGATOR, 1 MANHOLE, Done. (0.246s)
# image 269/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (66).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.244s)
# image 270/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (67).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.232s)
# image 271/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (68).JPG: 640x352 1 ALLIGATOR, Done. (0.242s)
# image 272/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (69).JPG: 640x352 1 ALLIGATOR, 1 LONGITUDINAL, Done. (0.236s)
# image 273/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (7).JPG: 640x352 1 BLOCK, 1 TRANSVERSE, 1 PATCHING, 1 LONGITUDINAL, Done. (0.248s)
# image 274/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (70).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, Done. (0.245s)
# image 275/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (71).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.256s)
# image 276/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (72).JPG: 640x352 2 ALLIGATORs, 2 TRANSVERSEs, Done. (0.240s)
# image 277/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (73).JPG: 640x352 3 ALLIGATORs, 1 LONGITUDINAL, Done. (0.246s)
# image 278/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (74).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, 2 MANHOLEs, Done. (0.242s)
# image 279/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (75).JPG: 640x352 3 ALLIGATORs, 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.248s)
# image 280/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (76).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, Done. (0.240s)
# image 281/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (77).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 PATCHING, Done. (0.239s)
# image 282/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (78).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.243s)
# image 283/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (79).JPG: 640x352 2 ALLIGATORs, Done. (0.251s)
# image 284/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (8).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, Done. (0.249s)
# image 285/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (80).JPG: 640x352 3 ALLIGATORs, 1 TRANSVERSE, Done. (0.245s)
# image 286/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (81).JPG: 640x352 2 ALLIGATORs, 1 BLOCK, Done. (0.247s)
# image 287/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (82).JPG: 640x352 1 ALLIGATOR, 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.238s)
# image 288/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (83).JPG: 640x352 1 LONGITUDINAL, Done. (0.250s)
# image 289/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (84).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.242s)
# image 290/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (85).JPG: 640x352 2 ALLIGATORs, Done. (0.241s)
# image 291/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (86).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.243s)
# image 292/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (87).JPG: 640x352 2 ALLIGATORs, 2 TRANSVERSEs, 1 PATCHING, 1 MANHOLE, Done. (0.241s)
# image 293/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (88).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 1 PATCHING, Done. (0.251s)
# image 294/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (89).JPG: 640x352 1 ALLIGATOR, 3 TRANSVERSEs, Done. (0.247s)
# image 295/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (9).JPG: 640x352 3 ALLIGATORs, Done. (0.243s)
# image 296/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (90).JPG: 640x352 1 TRANSVERSE, Done. (0.238s)
# image 297/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (91).JPG: 640x352 2 TRANSVERSEs, 1 PATCHING, 1 MANHOLE, Done. (0.246s)
# image 298/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (92).JPG: 640x352 1 MANHOLE, Done. (0.249s)
# image 299/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (93).JPG: 640x352 3 ALLIGATORs, Done. (0.240s)
# image 300/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (94).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.248s)
# image 301/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (95).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.238s)
# image 302/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (96).JPG: 640x352 4 TRANSVERSEs, 1 MANHOLE, Done. (0.241s)
# image 303/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (97).JPG: 640x352 1 ALLIGATOR, Done. (0.236s)
# image 304/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (98).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, Done. (0.238s)
# image 305/352 /content/drive/MyDrive/DSPS/data/test_images/images/8 (99).JPG: 640x352 2 ALLIGATORs, 1 PATCHING, Done. (0.254s)
# image 306/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (1).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.242s)
# image 307/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (10).JPG: 640x352 1 LONGITUDINAL, Done. (0.237s)
# image 308/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (11).JPG: 640x352 Done. (0.239s)
# image 309/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (12).JPG: 640x352 1 TRANSVERSE, Done. (0.243s)
# image 310/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (13).JPG: 640x352 1 TRANSVERSE, Done. (0.252s)
# image 311/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (14).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.241s)
# image 312/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (15).JPG: 640x352 1 LONGITUDINAL, Done. (0.255s)
# image 313/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (16).JPG: 640x352 1 LONGITUDINAL, Done. (0.242s)
# image 314/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (17).JPG: 640x352 1 PATCHING, 1 LONGITUDINAL, Done. (0.245s)
# image 315/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (18).JPG: 640x352 2 BLOCKs, 1 LONGITUDINAL, Done. (0.240s)
# image 316/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (19).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, Done. (0.235s)
# image 317/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (2).JPG: 640x352 1 PATCHING, Done. (0.250s)
# image 318/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (20).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.238s)
# image 319/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (21).JPG: 640x352 2 LONGITUDINALs, Done. (0.239s)
# image 320/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (22).JPG: 640x352 2 ALLIGATORs, 1 TRANSVERSE, 3 LONGITUDINALs, Done. (0.239s)
# image 321/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (23).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.236s)
# image 322/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (24).JPG: 640x352 1 LONGITUDINAL, Done. (0.247s)
# image 323/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (25).JPG: 640x352 3 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.241s)
# image 324/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (26).JPG: 640x352 1 LONGITUDINAL, Done. (0.242s)
# image 325/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (27).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.242s)
# image 326/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (28).JPG: 640x352 1 BLOCK, 6 TRANSVERSEs, 1 MANHOLE, Done. (0.237s)
# image 327/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (29).JPG: 640x352 2 TRANSVERSEs, Done. (0.247s)
# image 328/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (3).JPG: 640x352 1 TRANSVERSE, 3 LONGITUDINALs, Done. (0.239s)
# image 329/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (30).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.244s)
# image 330/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (31).JPG: 640x352 1 ALLIGATOR, 1 BLOCK, 2 TRANSVERSEs, 1 PATCHING, Done. (0.247s)
# image 331/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (32).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.250s)
# image 332/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (33).JPG: 640x352 1 ALLIGATOR, 4 TRANSVERSEs, Done. (0.274s)
# image 333/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (34).JPG: 640x352 1 TRANSVERSE, 1 MANHOLE, Done. (0.247s)
# image 334/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (35).JPG: 640x352 1 TRANSVERSE, Done. (0.239s)
# image 335/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (36).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, Done. (0.268s)
# image 336/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (37).JPG: 640x352 1 TRANSVERSE, 1 PATCHING, Done. (0.247s)
# image 337/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (38).JPG: 640x352 Done. (0.241s)
# image 338/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (39).JPG: 640x352 1 TRANSVERSE, 1 LONGITUDINAL, Done. (0.242s)
# image 339/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (4).JPG: 640x352 1 TRANSVERSE, Done. (0.238s)
# image 340/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (40).JPG: 640x352 2 TRANSVERSEs, 1 LONGITUDINAL, Done. (0.249s)
# image 341/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (41).JPG: 640x352 Done. (0.242s)
# image 342/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (42).JPG: 640x352 1 TRANSVERSE, 2 LONGITUDINALs, Done. (0.243s)
# image 343/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (43).JPG: 640x352 1 ALLIGATOR, 1 TRANSVERSE, Done. (0.258s)
# image 344/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (44).JPG: 640x352 Done. (0.249s)
# image 345/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (45).JPG: 640x352 1 PATCHING, Done. (0.246s)
# image 346/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (46).JPG: 640x352 1 ALLIGATOR, 1 PATCHING, Done. (0.262s)
# image 347/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (47).JPG: 640x352 2 PATCHINGs, 1 SEALING, Done. (0.246s)
# image 348/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (5).JPG: 640x352 Done. (0.245s)
# image 349/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (6).JPG: 640x352 1 LONGITUDINAL, Done. (0.241s)
# image 350/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (7).JPG: 640x352 2 TRANSVERSEs, Done. (0.242s)
# image 351/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (8).JPG: 640x352 2 TRANSVERSEs, 2 LONGITUDINALs, Done. (0.247s)
# image 352/352 /content/drive/MyDrive/DSPS/data/test_images/images/9 (9).JPG: 640x352 1 LONGITUDINAL, Done. (0.241s)

# %% [markdown]
# ### Upload submission.json file in the "results" folder to leaderboard

# %%
## sample submission file content
# [{"1 (134).JPG": [[3, 365, 585, 895, 697], [2, 41, 588, 917, 2000]]}, {"1 (154).JPG": [[1, 8, 1622, 429, 2007], [6, 24, 0, 157, 867]]}]
# [3, 365, 585, 895, 697] --> ['class','x1','y1','x2','y2']
# x1,y1 - top left corner of bounding box
# x2,y2 _ bottom right corner of bounding box

# %% [markdown]
# ### Auto Annotate and re-upload  to cvat

# %%
# !python 'dspYolov5/detect_dsps.py' --weights 'weights/train/exp/weights/best.pt' --img 640 --conf 0.25 --source data/auto_annotate/ --nosave

# %%
## this will create a cvat compatible annotation file 
img_path = 'data/test_images'
csv_path = 'results/submission.csv'
output_path = 'results/instances_default.json'
csv2cvat(csv_path, img_path,output_path)
